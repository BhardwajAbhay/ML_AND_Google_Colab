# %% [markdown]
# Input

# %%
import pandas as pd;
import numpy as np;
import matplotlib.pyplot as plt;
from sklearn import linear_model;

# %% [markdown]
# Import The CSV File

# %%
df = pd.read_csv("plotAreaPrice.csv")
df
# Out:
#    Area   Price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %% [markdown]
# Making a Graph

# %%
# %matplotlib inline

plt.xlabel('Area(sqr ft)')
plt.ylabel('Price (US$)')
plt.scatter(df.Area, df.Price, marker='+', color='red')
plt.plot(df.Area, reg.predict(df[['Area']]), color='blue')
plt.gca().set_facecolor('lightgray')
plt.gcf().set_facecolor('lightgray')
plt.show()

# %% [markdown]
# Training the Model

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['Area']], df.Price)

# %% [markdown]
# Testing the Model

# %%
reg.predict(pd.DataFrame({'Area': [3300]}))
# Out:
# array([628715.75342466])

# %%
reg.predict(pd.DataFrame({'Area': [5000]}))
# Out:
# array([859554.79452055])

# %%
d = pd.read_csv("plotArea.csv")
d
# Out:
#     Area        Prices
# 0   1000  3.164041e+05
# 1   1500  3.842979e+05
# 2   2200  4.793493e+05
# 3   3587  6.676868e+05
# 4   4510  7.930188e+05
# 5   7550  1.205813e+06
# 6   8546  1.341058e+06
# 7   7450  1.192235e+06
# 8   3364  6.374062e+05
# 9   3780  6.938938e+05
# 10  1789  4.235406e+05
# 11  2900  5.744007e+05
# 12  8560  1.342959e+06

# %%
p = reg.predict(d)

# %%
d['Prices'] = p
d

# %%
d.to_csv('plotArea.csv', index = False)
